# %%
import json

# Load all three datasets
with open("data/youtube.json") as f:
    yt = json.load(f)
with open("data/podcasts.json") as f:
    podcasts = json.load(f)
with open("data/webpages_by_tag_rich.json") as f:
    pages = json.load(f)

# Normalize all into one consistent structure
contents = []
for c in yt + podcasts + pages:
    contents.append({
        "title": c.get("title"),
        "description": c.get("description", ""),
        "source": c.get("source", "youtube" if "youtube" in c.get("link","") else "unknown"),
        "url": c.get("link") or c.get("url"),
        "tags": c.get("tags") if "tags" in c else [c.get("tag")] if "tag" in c else []
    })

# %%
pip install -q sentence-transformers
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('all-MiniLM-L6-v2')

# Load tag names from your tags.json
with open("data/tags.json") as f:
    tags_data = json.load(f)

all_tags = []
for cat in tags_data["categories"].values():
    all_tags.extend(cat["tags"])

# Embed all tag strings once
tag_embeds = model.encode(all_tags, convert_to_tensor=True)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
tagged_contents = []

for c in contents:
    # Combine title + description for embedding
    text = (c.get("title", "") or "") + " " + (c.get("description", "") or "")
    content_embed = model.encode(text, convert_to_tensor=True)
    scores = util.cos_sim(content_embed, tag_embeds)[0]
    
    # Get top 3 matching tags
    top_tags_idx = scores.topk(3).indices
    top_tags = [all_tags[i] for i in top_tags_idx]

    # Merge existing and new tags (avoid duplicates)
    existing_tags = c.get("tags", [])
    combined_tags = list(dict.fromkeys(existing_tags + top_tags))  # preserves order & removes duplicates

    # Update and store
    c["tags"] = combined_tags
    tagged_contents.append(c)

# %%
for c in tagged_contents:
    print(f"🎬 {c['title']}")
    print("   → Tags:", ", ".join(c["tags"]))
    print()
# Out:
# 🎬 What is AI Ethics?
#    → Tags: AI ethics, Artificial Intelligence, Data Science, Economics
#
# 🎬 AI Ethics | Ethics Defined
#    → Tags: AI ethics, Artificial Intelligence, Psychology, Economics
#
# 🎬 The Ethics of AI│Stuart J. Russell (University of California, Berkeley, Professor)
#    → Tags: AI ethics, Artificial Intelligence, Article, Economics
#
# 🎬 Ethics & AI: Equal Access and Algorithmic Bias
#    → Tags: AI ethics, Artificial Intelligence, Economics, Psychology
#
# 🎬 Ethics of AI: Challenges and Governance
#    → Tags: AI ethics, Artificial Intelligence, Innovation, Leadership
#
# 🎬 AI is an Ethical Nightmare
#    → Tags: AI ethics, Artificial Intelligence, Economics, Minimalism
#
# 🎬 AI Is Dangerous, but Not for the Reasons You Think | Sasha Luccioni | TED
#    → Tags: AI ethics, Artificial Intelligence, Documentaries, True Crime
#
# 🎬 How to implement AI Ethics
#    → Tags: AI ethics, Artificial Intelligence, Machine Learning, Management
#
# 🎬 EU AI Act with Punit Bhatia in the FIT4PRIVACY Podcast E150 S06
#    → Tags: AI ethics, Fiction Podcasts, Artificial Intelligence, Comedy
#
# 🎬 The three big ethical concerns with artificial intelligence
#    → Tags: AI ethics, Artificial Intelligence, Technology, Data Science
#
# 🎬 Global climate change limit efforts off-track for 2030 goals, new report shows
#    → Tags: climate change, Sustainability, Technology Trends, Chill
#
# 🎬 Questioning the "Science Is Settled" Climate Change Narrative
#    → Tags: climate change, Science, Sustainability, Documentaries
#
# 🎬 What Earth in 2050 could look like - Shannon Odell
#    → Tags: climate change, Sustainability, Technology Trends, World News
#
# 🎬 Climate change impacting Tropical Storm Melissa
#    → Tags: climate change, Data Science, Nature & Outdoors, Machine Learning
#
# 🎬 Climate change is woke #comedy #standup #standupcomedy #climatechange #politics #usa
#    → Tags: climate change, Sustainability, Stand-up, Comedy
#
# 🎬 Permafrost thawed by climate change threatens remote villages in Alaska
#    → Tags: climate change, Sustainability, Nature & Outdoors, Destination Guides
#
# 🎬 Human Caused Climate Change Is Faster Than Ever #ClimateChange #EarthScience #SSHQ
#    → Tags: climate change, Sustainability, Science, Technology
#
# 🎬 What Trump thinks about climate change
#    → Tags: climate change, Sustainability, Science, World News
#
# 🎬 The Green New Steal: The Business of Climate Change
#    → Tags: climate change, Sustainability, Innovation, Economics
#
# 🎬 What is Climate Change? Crash Course Geography #14
#    → Tags: climate change, Sustainability, Nature & Outdoors, History
#
# 🎬 Cryptography: Crash Course Computer Science #33
#    → Tags: cryptography, Artificial Intelligence, Data Science, Technology
#
# 🎬 7 Cryptography Concepts EVERY Developer Should Know
#    → Tags: cryptography, Data Science, Design Thinking, Finance
#
# 🎬 Cryptography Full Course | Cryptography And Network Security | Cryptography | Simplilearn
#    → Tags: cryptography, Artificial Intelligence, Data Science, Machine Learning
#
# 🎬 Lecture 1: Introduction to Cryptography by Christof Paar
#    → Tags: cryptography, Language Learning, Fiction Podcasts, Books & Literature
#
# 🎬 The Science of Codes: An Intro to Cryptography
#    → Tags: cryptography, Fiction Podcasts, Books & Literature, Data Science
#
# 🎬 Cryptography Basics: Intro to Cybersecurity
#    → Tags: cryptography, Data Science, Video, Remote Work
#
# 🎬 What is Cryptography | Cryptography Explained | Cryptography Basics | Intellipaat
#    → Tags: cryptography, Finance, Technology, Data Science
#
# 🎬 Encryption and public keys | Internet 101 | Computer Science | Khan Academy
#    → Tags: cryptography, Data Science, Remote Work, Artificial Intelligence
#
# 🎬 Cryptography 101 - The Basics
#    → Tags: cryptography, Video, Audio, Data Science
#
# 🎬 What is cryptography? | Journey into cryptography | Computer Science | Khan Academy
#    → Tags: cryptography, Educational, Education, Data Science
#
# 🎬 Data Visualization in 2025 | The Ultimate Guide
#    → Tags: data visualization, Data Science, Technology Trends, Technology
#
# 🎬 The beauty of data visualization - David McCandless
#    → Tags: data visualization, Data Science, Machine Learning, Design Thinking
#
# 🎬 The Art of Data Visualization | Off Book | PBS Digital Studios
#    → Tags: data visualization, Documentaries, TV Shows, Data Science
#
# 🎬 Data Visualization Tutorial For Beginners | Big Data Analytics Tutorial | Simplilearn
#    → Tags: data visualization, Data Science, Trending, Product Management
#
# 🎬 Data Visualization Crash Course | Consulting Best Practices
#    → Tags: data visualization, Data Science, Video, Focus
#
# 🎬 Data Visualization with D3, JavaScript, React - Full Course
#    → Tags: data visualization, Data Science, Design Thinking, Educational
#
# 🎬 Data Visualization with D3 – Full Course for Beginners
#    → Tags: data visualization, Data Science, Destination Guides, Educational
#
# 🎬 Data Visualization and Misrepresentation
#    → Tags: data visualization, Data Science, Machine Learning, Trending
#
# 🎬 Data Analyst Tutorial #4 Charts in Google Sheets | Visualize Data Like a Pro #dataanalyst
#    → Tags: data visualization, Data Science, Productivity, Machine Learning
#
# 🎬 Effective Data Visualisation - with Valentina D'Efilippo
#    → Tags: data visualization, Data Science, Productivity, Trending
#
# 🎬 #371 – Max Tegmark: The Case for Halting AI Development
#    → Tags: artificial intelligence, Artificial Intelligence, Technology, Fiction Podcasts
#
# 🎬 #365 – Sam Harris: Trump, Pandemic, Twitter, Elon, Bret, IDW, Kanye, AI & UFOs
#    → Tags: artificial intelligence, Fiction Podcasts, Documentaries, Audio
#
# 🎬 #323 – Will Sasso: Comedy, MADtv, AI, Friendship, Madness, and Pro Wrestling
#    → Tags: artificial intelligence, Fiction Podcasts, TV Shows, Comedy
#
# 🎬 #312 – Duncan Trussell: Comedy, Sentient Robots, Suffering, Love & Burning Man
#    → Tags: artificial intelligence, Fiction Podcasts, Comedy, Adventure
#
# 🎬 #302 – Richard Haier: IQ Tests, Human Intelligence, and Group Differences
#    → Tags: artificial intelligence, Psychology, Mental Health, Artificial Intelligence
#
# 🎬 #292 – Robin Hanson: Alien Civilizations, UFOs, and the Future of Humanity
#    → Tags: artificial intelligence, Fiction Podcasts, Documentaries, Audio
#
# 🎬 #258 – Yann LeCun: Dark Matter of Intelligence and Self-Supervised Learning
#    → Tags: artificial intelligence, Artificial Intelligence, Language Learning, Machine Learning
#
# 🎬 #240 – Neal Stephenson: Sci-Fi, Space, Aliens, AI, VR & the Future of Humanity
#    → Tags: artificial intelligence, Fiction Podcasts, Adventure, Finance
#
# 🎬 #169 – Ryan Hall: Solving Martial Arts from First Principles
#    → Tags: artificial intelligence, Fiction Podcasts, Health & Fitness, Yoga
#
# 🎬 #168 – Silvio Micali: Cryptocurrency, Blockchain, Algorand, Bitcoin, and Ethereum
#    → Tags: cryptography, Finance, Fiction Podcasts, Investing
#
# 🎬 #149 – Diana Walsh Pasulka: Aliens, Technology, Religion, and the Nature of Belief
#    → Tags: artificial intelligence, Fiction Podcasts, Documentaries, Audio
#
# 🎬 #115 – Dileep George: Brain-Inspired AI
#    → Tags: artificial intelligence, Artificial Intelligence, Fiction Podcasts, Meditation
#
# 🎬 #106 – Matt Botvinick: Neuroscience, Psychology, and AI at DeepMind
#    → Tags: artificial intelligence, Fiction Podcasts, Artificial Intelligence, Psychology
#
# 🎬 #105 – Robert Langer: Edison of Medicine
#    → Tags: artificial intelligence, Fiction Podcasts, Technology, Innovation
#
# 🎬 #104 – David Patterson: Computer Architecture and Data Storage
#    → Tags: artificial intelligence, Data Science, Artificial Intelligence, Technology
#
# 🎬 #103 – Ben Goertzel: Artificial General Intelligence
#    → Tags: artificial intelligence, Artificial Intelligence, Machine Learning, Innovation
#
# 🎬 #102 – Steven Pressfield: The War of Art
#    → Tags: artificial intelligence, Fiction Podcasts, Books & Literature, Documentaries
#
# 🎬 #101 – Joscha Bach: Artificial Consciousness and the Nature of Reality
#    → Tags: artificial intelligence, Artificial Intelligence, Fiction Podcasts, Meditation
#
# 🎬 #99 – Karl Friston: Neuroscience and the Free Energy Principle
#    → Tags: artificial intelligence, Fiction Podcasts, Psychology, Meditation
#
# 🎬 #97 – Sertac Karaman: Robots That Fly and Robots That Drive
#    → Tags: artificial intelligence, Fiction Podcasts, Destination Guides, Adventure
#
# 🎬 #96 – Stephen Schwarzman: Going Big in Business, Investing, and AI
#    → Tags: artificial intelligence, Entrepreneurship, Finance, Artificial Intelligence
#
# 🎬 #95 – Dawn Song: Adversarial Machine Learning and Computer Security
#    → Tags: artificial intelligence, Fiction Podcasts, Artificial Intelligence, Audio
#
# 🎬 #94 – Ilya Sutskever: Deep Learning
#    → Tags: artificial intelligence, Fiction Podcasts, Documentaries, Audio
#
# 🎬 #93 – Daphne Koller: Biomedicine and Machine Learning
#    → Tags: artificial intelligence, Fiction Podcasts, Data Science, Artificial Intelligence
#
# 🎬 #92 – Harry Cliff: Particle Physics and the Large Hadron Collider
#    → Tags: artificial intelligence, Science, Finance, Adventure
#
# 🎬 #91 – Jack Dorsey: Square, Cryptocurrency, and Artificial Intelligence
#    → Tags: artificial intelligence, Fiction Podcasts, Audio, Article
#
# 🎬 #90 – Dmitry Korkin: Computational Biology of Coronavirus
#    → Tags: artificial intelligence, Data Science, Technology, Artificial Intelligence
#
# 🎬 #89 – Stephen Wolfram: Cellular Automata, Computation, and Physics
#    → Tags: artificial intelligence, Artificial Intelligence, Technology, Data Science
#
# 🎬 #88 – Eric Weinstein: Geometric Unity and the Call for New Ideas, Leaders & Institutions
#    → Tags: artificial intelligence, Economics, Minimalism, Finance
#
# 🎬 #87 – Richard Dawkins: Evolution, Intelligence, Simulation, and Memes
#    → Tags: artificial intelligence, Lifestyle, Economics, Science
#
# 🎬 #86 – David Silver: AlphaGo, AlphaZero, and Deep Reinforcement Learning
#    → Tags: artificial intelligence, Artificial Intelligence, Finance, Investing
#
# 🎬 #85 – Roger Penrose: Physics of Consciousness and the Infinite Universe
#    → Tags: artificial intelligence, Fiction Podcasts, Meditation, Artificial Intelligence
#
# 🎬 #83 – Nick Bostrom: Simulation and Superintelligence
#    → Tags: artificial intelligence, Artificial Intelligence, Fiction Podcasts, Innovation
#
# 🎬 #82 – Simon Sinek: Leadership, Hard Work, Optimism and the Infinite Game
#    → Tags: artificial intelligence, Leadership, Motivational, Entrepreneurship
#
# 🎬 #81 – Anca Dragan: Human-Robot Interaction and Reward Engineering
#    → Tags: artificial intelligence, Artificial Intelligence, Fiction Podcasts, Language Learning
#
# 🎬 #80 – Vitalik Buterin: Ethereum, Cryptocurrency, and the Future of Money
#    → Tags: artificial intelligence, Finance, Investing, Technology Trends
#
# 🎬 #79 – Lee Smolin: Quantum Gravity and Einstein’s Unfinished Revolution
#    → Tags: artificial intelligence, Fiction Podcasts, Artificial Intelligence, Minimalism
#
# 🎬 #78 – Ann Druyan: Cosmos, Carl Sagan, Voyager, and the Beauty of Science
#    → Tags: artificial intelligence, Fiction Podcasts, Documentaries, Science
#
# 🎬 #77 – Alex Garland: Ex Machina, Devs, Annihilation, and the Poetry of Science
#    → Tags: artificial intelligence, Fiction Podcasts, Documentaries, Movies
#
# 🎬 #76 – John Hopfield: Physics View of the Mind and Neurobiology
#    → Tags: artificial intelligence, Artificial Intelligence, Science, Psychology
#
# 🎬 #75 – Marcus Hutter: Universal Artificial Intelligence, AIXI, and AGI
#    → Tags: artificial intelligence, Artificial Intelligence, Machine Learning, Language Learning
#
# 🎬 #74 – Michael I. Jordan: Machine Learning, Recommender Systems, and the Future of AI
#    → Tags: artificial intelligence, Artificial Intelligence, Machine Learning, Fiction Podcasts
#
# 🎬 #73 – Andrew Ng: Deep Learning, Education, and Real-World AI
#    → Tags: artificial intelligence, Artificial Intelligence, Education, Educational
#
# 🎬 #72 – Scott Aaronson: Quantum Computing
#    → Tags: artificial intelligence, cryptography, Fiction Podcasts, Audio, Artificial Intelligence
#
# 🎬 Vladimir Vapnik: Predicates, Invariants, and the Essence of Intelligence
#    → Tags: artificial intelligence, Artificial Intelligence, Machine Learning, Language Learning
#
# 🎬 Jim Keller: Moore’s Law, Microprocessors, Abstractions, and First Principles
#    → Tags: artificial intelligence, Artificial Intelligence, Fiction Podcasts, Technology Trends
#
# 🎬 David Chalmers: The Hard Problem of Consciousness
#    → Tags: artificial intelligence, Fiction Podcasts, Audio, Meditation
#
# 🎬 Cristos Goodrow: YouTube Algorithm
#    → Tags: artificial intelligence, Fiction Podcasts, Documentaries, Video
#
# 🎬 Paul Krugman: Economics of Innovation, Automation, Safety Nets & Universal Basic Income
#    → Tags: artificial intelligence, Economics, Finance, Personal Finance
#
# 🎬 Ayanna Howard: Human-Robot Interaction and Ethics of Safety-Critical Systems
#    → Tags: artificial intelligence, Fiction Podcasts, Remote Work, Audio
#
# 🎬 Daniel Kahneman: Thinking Fast and Slow, Deep Learning, and AI
#    → Tags: artificial intelligence, Economics, Artificial Intelligence, Psychology
#
# 🎬 Grant Sanderson: 3Blue1Brown and the Beauty of Mathematics
#    → Tags: artificial intelligence, Fiction Podcasts, Audio, Artificial Intelligence
#
# 🎬 Stephen Kotkin: Stalin, Putin, and the Nature of Power
#    → Tags: artificial intelligence, Fiction Podcasts, Documentaries, Audio
#
# 🎬 Donald Knuth: Algorithms, TeX, Life, and The Art of Computer Programming
#    → Tags: artificial intelligence, Data Science, Artificial Intelligence, Fiction Podcasts
#
# 🎬 Melanie Mitchell: Concepts, Analogies, Common Sense & Future of AI
#    → Tags: artificial intelligence, Artificial Intelligence, Psychology, Fiction Podcasts
#
# 🎬 Jim Gates: Supersymmetry, String Theory and Proving Einstein Right
#    → Tags: artificial intelligence, Fiction Podcasts, Artificial Intelligence, Science
#
# 🎬 Sebastian Thrun: Flying Cars, Autonomous Vehicles, and Education
#    → Tags: artificial intelligence, Artificial Intelligence, Educational, Documentaries
#
# 🎬 Michael Stevens: Vsauce
#    → Tags: artificial intelligence, Fiction Podcasts, Mindfulness, Psychology
#
# 🎬 Rohit Prasad: Amazon Alexa and Conversational AI
#    → Tags: artificial intelligence, Fiction Podcasts, Audio, Documentaries
#
# 🎬 Judea Pearl: Causal Reasoning, Counterfactuals, Bayesian Networks, and the Path to AGI
#    → Tags: artificial intelligence, Artificial Intelligence, Economics, Data Science
#
# 🎬 Whitney Cummings: Comedy, Robotics, Neurology, and Love
#    → Tags: artificial intelligence, Fiction Podcasts, Artificial Intelligence, Documentaries
#
# 🎬 Ray Dalio: Principles, the Economic Machine, Artificial Intelligence & the Arc of Life
#    → Tags: artificial intelligence, Economics, Artificial Intelligence, Finance
#
# 🎬 Noam Chomsky: Language, Cognition, and Deep Learning
#    → Tags: artificial intelligence, Fiction Podcasts, Language Learning, Audio
#
# 🎬 Gilbert Strang: Linear Algebra, Deep Learning, Teaching, and MIT OpenCourseWare
#    → Tags: artificial intelligence, Fiction Podcasts, Language Learning, Artificial Intelligence
#
# 🎬 Dava Newman: Space Exploration, Space Suits, and Life on Mars
#    → Tags: artificial intelligence, Fiction Podcasts, Documentaries, Health & Fitness
#
# 🎬 Michael Kearns: Algorithmic Fairness, Bias, Privacy, and Ethics in Machine Learning
#    → Tags: artificial intelligence, Economics, Artificial Intelligence, Machine Learning
#
# 🎬 Elon Musk: Neuralink, AI, Autopilot, and the Pale Blue Dot
#    → Tags: artificial intelligence, Fiction Podcasts, Artificial Intelligence, Documentaries
#
# 🎬 Bjarne Stroustrup: C++
#    → Tags: artificial intelligence, Artificial Intelligence, Fiction Podcasts, Technology Trends
#
# 🎬 Sean Carroll: Quantum Mechanics and the Many-Worlds Interpretation
#    → Tags: artificial intelligence, Fiction Podcasts, Documentaries, Meditation
#
# 🎬 Garry Kasparov: Chess, Deep Blue, AI, and Putin
#    → Tags: artificial intelligence, Artificial Intelligence, Gaming, Leadership
#
# 🎬 Michio Kaku: Future of Humans, Aliens, Space Travel & Physics
#    → Tags: artificial intelligence, Fiction Podcasts, Documentaries, Science
#
# 🎬 David Ferrucci: IBM Watson, Jeopardy & Deep Conversations with AI
#    → Tags: artificial intelligence, Artificial Intelligence, Psychology, Machine Learning
#
# 🎬 Gary Marcus: Toward a Hybrid of Deep Learning and Symbolic AI
#    → Tags: artificial intelligence, Artificial Intelligence, Machine Learning, Fiction Podcasts
#
# 🎬 Peter Norvig: Artificial Intelligence: A Modern Approach
#    → Tags: artificial intelligence, Artificial Intelligence, Fiction Podcasts, Machine Learning
#
# 🎬 Leonard Susskind: Quantum Mechanics, String Theory, and Black Holes
#    → Tags: artificial intelligence, Fiction Podcasts, Science, Artificial Intelligence
#
# 🎬 Regina Barzilay: Deep Learning for Cancer Diagnosis and Treatment
#    → Tags: artificial intelligence, Fiction Podcasts, Machine Learning, Documentaries
#
# 🎬 Colin Angle: iRobot
#    → Tags: artificial intelligence, Artificial Intelligence, Entrepreneurship, Innovation
#
# 🎬 François Chollet: Keras, Deep Learning, and the Progress of AI
#    → Tags: artificial intelligence, Artificial Intelligence, Fiction Podcasts, Machine Learning
#
# 🎬 Vijay Kumar: Flying Robots
#    → Tags: artificial intelligence, Artificial Intelligence, Documentaries, Fiction Podcasts
#
# 🎬 Yann LeCun: Deep Learning, Convolutional Neural Networks, and Self-Supervised Learning
#    → Tags: artificial intelligence, Fiction Podcasts, Artificial Intelligence, Documentaries
#
# 🎬 Jeremy Howard: fast.ai Deep Learning Courses and Research
#    → Tags: artificial intelligence, Fiction Podcasts, Artificial Intelligence, Educational
#
# 🎬 Pamela McCorduck: Machines Who Think and the Early Days of AI
#    → Tags: artificial intelligence, Artificial Intelligence, Technology, Innovation
#
# 🎬 Keoki Jackson: Lockheed Martin
#    → Tags: artificial intelligence, Fiction Podcasts, Documentaries, Artificial Intelligence
#
# 🎬 Paola Arlotta: Brain Development from Stem Cell to Organoid
#    → Tags: artificial intelligence, Fiction Podcasts, Artificial Intelligence, Science
#
# 🎬 George Hotz: Comma.ai, OpenPilot, and Autonomous Vehicles
#    → Tags: artificial intelligence, Artificial Intelligence, Fiction Podcasts, Innovation
#
# 🎬 Kevin Scott: Microsoft CTO
#    → Tags: artificial intelligence, Artificial Intelligence, Innovation, Marketing
#
# 🎬 Gustav Soderstrom: Spotify
#    → Tags: artificial intelligence, Music, Audio, Fiction Podcasts
#
# 🎬 Chris Urmson: Self-Driving Cars at Aurora, Google, CMU, and DARPA
#    → Tags: artificial intelligence, Fiction Podcasts, Documentaries, Artificial Intelligence
#
# 🎬 Kai-Fu Lee: AI Superpowers – China and Silicon Valley
#    → Tags: artificial intelligence, Artificial Intelligence, Technology Trends, Innovation
#
# 🎬 Jeff Hawkins: Thousand Brains Theory of Intelligence
#    → Tags: artificial intelligence, Artificial Intelligence, Psychology, Fiction Podcasts
#
# 🎬 Juergen Schmidhuber: Godel Machines, Meta-Learning, and LSTMs
#    → Tags: artificial intelligence, Fiction Podcasts, Language Learning, Artificial Intelligence
#
# 🎬 Stuart Russell: Long-Term Future of AI
#    → Tags: artificial intelligence, Artificial Intelligence, Data Science, Machine Learning
#
# 🎬 Vladimir Vapnik: Statistical Learning
#    → Tags: artificial intelligence, Artificial Intelligence, Machine Learning, Language Learning
#
# 🎬 Max Tegmark: Life 3.0
#    → Tags: artificial intelligence, Artificial Intelligence, Science, Minimalism
#
# 🎬 artificial intelligence
#    → Tags: artificial intelligence, Artificial Intelligence, Machine Learning, Data Science
#
# 🎬 Watch Live Breaking News
#    → Tags: artificial intelligence, World News, Documentaries, Personal Finance
#
# 🎬 Breaking News, World News, US News, Sports, Business, Innovation, Climate, Culture, Travel, Video & Audio
#    → Tags: artificial intelligence, World News, Pop Culture, Entertainment
#
# 🎬 Breaking News, World News, US News, Sports, Business, Innovation, Climate, Culture, Travel, Video & Audio
#    → Tags: artificial intelligence, World News, Pop Culture, Entertainment
#
# 🎬 Breaking news, video and the latest top stories from the U.S. and around the world
#    → Tags: artificial intelligence, Relaxing, Entertainment, Reflective
#
# 🎬 Breaking News, US News, World News and Videos
#    → Tags: artificial intelligence, World News, Movies, Documentaries
#
# 🎬 Today's Paper
#    → Tags: artificial intelligence, Article, True Crime, Psychology
#
# 🎬 Artificial Intelligence
#    → Tags: artificial intelligence, Artificial Intelligence, Psychology, Remote Work
#
# 🎬 data visualization
#    → Tags: data visualization, Data Science, Trending, Machine Learning
#
# 🎬 Watch Live Breaking News
#    → Tags: data visualization, World News, Documentaries, Personal Finance
#
# 🎬 Breaking News, World News, US News, Sports, Business, Innovation, Climate, Culture, Travel, Video & Audio
#    → Tags: data visualization, World News, Pop Culture, Entertainment
#
# 🎬 Breaking News, World News, US News, Sports, Business, Innovation, Climate, Culture, Travel, Video & Audio
#    → Tags: data visualization, World News, Pop Culture, Entertainment
#
# 🎬 Breaking news, video and the latest top stories from the U.S. and around the world
#    → Tags: data visualization, Relaxing, Entertainment, Reflective
#
# 🎬 Breaking News, US News, World News and Videos
#    → Tags: data visualization, World News, Movies, Documentaries
#
# 🎬 Today's Paper
#    → Tags: data visualization, Article, True Crime, Psychology
#
# 🎬 Growing Up With A.I.: A Multimedia Challenge for Teenagers and Educators
#    → Tags: data visualization, Educational, Education, Motivational
#
# 🎬 climate change
#    → Tags: climate change, Sustainability, Trending, Nature & Outdoors
#
# 🎬 Watch Live Breaking News
#    → Tags: climate change, World News, Documentaries, Personal Finance
#
# 🎬 Breaking News, World News, US News, Sports, Business, Innovation, Climate, Culture, Travel, Video & Audio
#    → Tags: climate change, World News, Pop Culture, Entertainment
#
# 🎬 Breaking News, World News, US News, Sports, Business, Innovation, Climate, Culture, Travel, Video & Audio
#    → Tags: climate change, World News, Pop Culture, Entertainment
#
# 🎬 Breaking news, video and the latest top stories from the U.S. and around the world
#    → Tags: climate change, Relaxing, Entertainment, Reflective
#
# 🎬 Breaking News, US News, World News and Videos
#    → Tags: climate change, World News, Movies, Documentaries
#
# 🎬 Today's Paper
#    → Tags: climate change, Article, True Crime, Psychology
#
# 🎬 Art and Data Team Up Against Climate Change
#    → Tags: climate change, Nature & Outdoors, Sustainability, Relaxing
